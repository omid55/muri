# %%
import skill_learning
import imp

# %%
skill_learning = imp.reload(skill_learning)
skill_learning.run(number_of_people=10, team_size=2, iterations=100, runs=10)
# Out:
# Method by_random:  **********
# Method by_epsilon_optimal:  **********
# Method by_ucb:  **********
# Method by_thompson_sampling:  **********
# Method by_ucb_with_random_variable_per_node:  **********
# Method by_thompson_sampling_with_random_variable_per_node:  **********

# %%
skill_learning = imp.reload(skill_learning)
skill_learning.run(number_of_people=10, team_size=3, iterations=1000, runs=10)
# Out:
# Method by_random:  **********
# Method by_epsilon_optimal:  **********
# Method by_ucb:  **********
# Method by_thompson_sampling:  **********
# Method by_ucb_with_random_variable_per_node:  **********
# Method by_thompson_sampling_with_random_variable_per_node:  **********

# %%
skill_learning = imp.reload(skill_learning)
skill_learning.run(number_of_people=15, team_size=3, iterations=1000, runs=10)
# Out:
# Method by_random:  **********(in  2.54  seconds)
# Method by_epsilon_optimal:  **********(in  2.92  seconds)
# Method by_ucb:  **********(in  5.26  seconds)
# Method by_thompson_sampling:  **********(in  230.83  seconds)
# Method by_ucb_with_random_variable_per_node:  **********(in  2.62  seconds)
# Method by_thompson_sampling_with_random_variable_per_node:  **********(in  10.18  seconds)
