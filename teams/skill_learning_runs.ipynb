# %%
import skill_learning
import imp

# %%
skill_learning = imp.reload(skill_learning)
skill_learning.run(number_of_people=10, team_size=2, iterations=100, runs=10)
# Out:
# Method by_random:  ********** (in  1.17  seconds)
# Method by_explore_then_exploit:  ********** (in  1.21  seconds)
# Method by_qlearning:  ********** (in  1.24  seconds)
# Method by_eplison_greedy:  ********** (in  1.42  seconds)
# Method by_likelihood:  ********** (in  1.38  seconds)
# Method by_ucb:  ********** (in  1.29  seconds)
# Method by_thompson_sampling:  ********** (in  3.3  seconds)
# Method by_ucb_with_random_variable_per_node:  ********** (in  1.21  seconds)
# Method by_thompson_sampling_with_random_variable_per_node:  ********** (in  1.75  seconds)

# %%
skill_learning = imp.reload(skill_learning)
skill_learning.run(number_of_people=10, team_size=3, iterations=1000, runs=10)
# Out:
# Method by_random:  ********** (in  2.65  seconds)
# Method by_explore_then_exploit:  ********** (in  2.85  seconds)
# Method by_qlearning:  ********** (in  2.71  seconds)
# Method by_eplison_greedy:  ********** (in  2.68  seconds)
# Method by_likelihood:  ********** (in  3.04  seconds)
# Method by_ucb:  ********** (in  3.76  seconds)
# Method by_thompson_sampling:  ********** (in  54.67  seconds)
# Method by_ucb_with_random_variable_per_node:  ********** (in  2.59  seconds)
# Method by_thompson_sampling_with_random_variable_per_node:  ********** (in  6.83  seconds)

# %%
skill_learning = imp.reload(skill_learning)
skill_learning.run(number_of_people=15, team_size=3, iterations=1000, runs=10)
# Out:
# Method by_random:  ********** (in  2.37  seconds)
# Method by_explore_then_exploit:  ********** (in  2.83  seconds)
# Method by_qlearning:  ********** (in  2.51  seconds)
# Method by_eplison_greedy:  ********** (in  2.92  seconds)
# Method by_likelihood:  ********** (in  4.33  seconds)
# Method by_ucb:  ********** (in  5.21  seconds)
# Method by_thompson_sampling:  ********** (in  204.09  seconds)
# Method by_ucb_with_random_variable_per_node:  ********** (in  2.81  seconds)
# Method by_thompson_sampling_with_random_variable_per_node:  ********** (in  11.43  seconds)

# %%
skill_learning = imp.reload(skill_learning)
skill_learning.run(number_of_people=20, team_size=4, iterations=5000, runs=10)
# Out:
# Method by_random:  ********** (in  8.0  seconds)
# Method by_explore_then_exploit:  ********** (in  17.23  seconds)
# Method by_qlearning:  ********** (in  8.51  seconds)
# Method by_eplison_greedy:  ********** (in  15.72  seconds)
# Method by_likelihood:  ********** (in  93.84  seconds)
# Method by_ucb:  ********** (in  14.9  seconds)
# Method by_ucb_with_random_variable_per_node:  ********** (in  6.84  seconds)
# Method by_thompson_sampling_with_random_variable_per_node:  ********** (in  48.45  seconds)

# %%
skill_learning = imp.reload(skill_learning)
skill_learning.run(number_of_people=20, team_size=4, iterations=5000, runs=20)
# Out:
# Method by_random:  ******************** (in  15.02  seconds)
# Method by_explore_then_exploit:  ******************** (in  33.63  seconds)
# Method by_qlearning:  ******************** (in  17.13  seconds)
# Method by_eplison_greedy:  ******************** (in  31.42  seconds)
# Method by_likelihood:  ******************** (in  191.68  seconds)
# Method by_ucb:  ******************** (in  29.99  seconds)
# Method by_ucb_with_random_variable_per_node:  ******************** (in  13.75  seconds)
# Method by_thompson_sampling_with_random_variable_per_node:  ******************** (in  97.56  seconds)

# %%
skill_learning = imp.reload(skill_learning)
skill_learning.run(number_of_people=20, team_size=4, iterations=5000, runs=1)
# Out:
# Method by_random:  * (in  0.82  seconds)
# Method by_explore_then_exploit:  * (in  1.75  seconds)
# Method by_qlearning:  * (in  0.86  seconds)
# Method by_eplison_greedy:  * (in  1.98  seconds)
# Method by_likelihood:  * (in  9.71  seconds)
# Method by_ucb:  * (in  1.96  seconds)
# Method by_ucb_with_random_variable_per_node:  * (in  0.69  seconds)
# Method by_thompson_sampling_with_random_variable_per_node:  * (in  4.85  seconds)

# %% [markdown]
# # NEW

# %%
skill_learning = imp.reload(skill_learning)
skill_learning.run(number_of_people=20, team_size=4, iterations=1000, runs=20)
# Out:
# Method by_random:  ******************** (in  5.5  seconds)
# Method by_explore_then_exploit:  ******************** (in  6.31  seconds)
# Method by_classification:  ******************** (in  50.08  seconds)
# Method by_thompson_sampling_with_random_variable_per_node:  ******************** (in  23.98  seconds)

# %%
skill_learning = imp.reload(skill_learning)
skill_learning.run(number_of_people=20, team_size=4, iterations=1000, runs=20)
# Out:
# Method by_random:  ******************** (in  5.08  seconds)
# Method by_explore_then_exploit:  ******************** (in  5.71  seconds)
# Method by_online_classification:  ****************
